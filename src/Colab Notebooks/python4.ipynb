# %%
class Calculator:
    def __init__(self):
        self.result = 0
        self.operator = ["add", "sub", "mul", "div"]
        print (self.operator)

    def add(self, *args):
        print ("Add operator : ")
        for i in args:
            self.result = self.result + i
            print("%d" %(i), end=" + ")
        print (" = ", end= " ")
        print (self.result)
        return self.result

    def sub(self, *args):
        print ("Sub operator : ")
        for i in args:
            self.result = self.result - i
            print("%d" %(i), end=" - ")
        print (" = ", end= " ")
        print (self.result)
        return self.result

    def mul(self, *args):
        print ("Mul operator : ")
        for i in args:
            self.result = self.result * i
            print("%d" %(i), end=" x ")
        print (" = ", end= " ")
        print (self.result)
        return self.result

    def div(self, *args):
        print ("Div operator : ")
        for i in args:
            self.result = self.result / i
            print("%d" %(i), end=" / ")
        print (" = ", end= " ")
        print (self.result)
        return self.result


calc1 = Calculator()
calc1.add(10, 20, 30)
calc1.mul(2)
# Out:
# ['add', 'sub', 'mul', 'div']
# Add operator :
# 10 + 20 + 30 +  =  60
# Mul operator :
# 2 x  =  120
# 120

# %%
class Super_calculator(Calculator):
    def __init__(self):
        super(Super_calculator, self).__init__()
        self.operator.append("integral")
        print (self.operator)

    def integral(self):
        print ("integral x is 0.5x^2")

    def power2(self, num):
        self.result = num
        print (self.result**2)


calcSup = Super_calculator()
calcSup.integral()
calcSup.power2(25.55)
# Out:
# ['add', 'sub', 'mul', 'div']
# ['add', 'sub', 'mul', 'div', 'integral']
# integral x is 0.5x^2
# 652.8025

# %%
from python3 import func_kwargs

func_kwargs(1, 2, 3,55, name="parkSH", age=222)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-4e41f0af0c8c> in <module>()
# ----> 1 from python3 import func_kwargs
#       2
#       3 func_kwargs(1, 2, 3,55, name="parkSH", age=222)
#
# ModuleNotFoundError: No module named 'python3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# for colab users
rom google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-49a0f774-68cb-4112-beb8-a5b6a895dab3" name="files[]" multiple disabled />
#      <output id="result-49a0f774-68cb-4112-beb8-a5b6a895dab3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving python3.py to python3.py
# {'python3.py': b'#!~/Documents/tensorflowVE3/bin/python3\n\n\'\'\'\nIntroduction to Python\nREF : Jump to Python / https://docs.python.org/3/tutorial/index.html\n\'\'\'\n\n\ndef printhello():\n    print ("Hello!!!")\n\n\nprinthello()\n\n\ndef sum(a, b):\n    return a + b\n\n\nprint (sum(10, 20))\n\n\ndef sum_many(*args):\n    sum = 0\n    for i in args:\n        sum = sum + i\n    return sum\n\n\nprint (sum_many(10, 20, 30, 50, 600))\n\n\ndef func_kwargs(*args, **kwargs):\n    print (args)\n    print (kwargs)\n\n\nfunc_kwargs(1, 2, 3, name="parkSH", age=22)\n\nwhile(True):\n    number = input("\xec\x95\x84\xeb\xac\xb4 \xec\x88\xab\xec\x9e\x90\xeb\x82\x98 \xec\x9e\x85\xeb\xa0\xa5\xed\x95\x98\xec\x84\xb8\xec\x9a\x94 \\n")\n    # isdigit() isalnum() isalpha() isnumeric()\n    if number.isdigit() is True:\n        print ("input is : %s\\n" % (number))\n        break\n    else:\n        continue\n\nimport os\n\ncwd = os.getcwd()\nfile_dir = cwd + "/pythontext.txt"\nfile_1 = open(file_dir, "r")\nwhile (True):\n    # file_1.readlines()\n    line = file_1.readline()\n    if not line:\n        break\n    print (line)\nfile_1.close()\n\nwith open(file_dir, \'a\') as f:\n    f.write("Life is too short, write in Python")\n\nfile_1 = open(file_dir, "r")\nwhile (True):\n    # file_1.readlines()\n    line = file_1.readline()\n    if not line:\n        break\n    print (line)\nfile_1.close()\n\n\'\'\'\nHello!!!\n30\n710\n(1, 2, 3)\n{\'age\': 22, \'name\': \'parkSH\'}\n\xec\x95\x84\xeb\xac\xb4 \xec\x88\xab\xec\x9e\x90\xeb\x82\x98 \xec\x9e\x85\xeb\xa0\xa5\xed\x95\x98\xec\x84\xb8\xec\x9a\x94\n3\ninput is : 3\n\ntitle : pythontext\n\nformat : txt\n\ntitle : pythontext\n\nformat : txt\n\nLife is too short, write in Python\n\'\'\'\n'}

# %%
from python3 import func_kwargs

func_kwargs(1, 2, 3,55, name="parkSH", age=222)
# Out:
# Hello!!!
# 30
# 710
# (1, 2, 3)
# {'name': 'parkSH', 'age': 22}
